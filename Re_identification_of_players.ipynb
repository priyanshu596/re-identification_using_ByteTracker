# %%
# !pip install ultralytics --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 95.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.1 MB/s eta 0:00:00

# %%
# Step 1: Install gdown if not already installed
# !pip install -U gdown

# Step 2: Use gdown with file ID to download the actual model
# !gdown --id 1-5fOSHOSB9UXyP_enOoZNAMScrePVcMD --output best.pt
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1-5fOSHOSB9UXyP_enOoZNAMScrePVcMD
# From (redirected): https://drive.google.com/uc?id=1-5fOSHOSB9UXyP_enOoZNAMScrePVcMD&confirm=t&uuid=5992bcf5-1390-41c1-9296-f2f3e7e06c39
# To: /content/best.pt
# 100% 195M/195M [00:03<00:00, 61.1MB/s]

# %%
# !git clone https://github.com/ifzhang/ByteTrack.git
# %cd ByteTrack
# Out:
# Cloning into 'ByteTrack'...
# remote: Enumerating objects: 2007, done.
# remote: Total 2007 (delta 0), reused 0 (delta 0), pack-reused 2007 (from 1)
# Receiving objects: 100% (2007/2007), 79.60 MiB | 16.10 MiB/s, done.
# Resolving deltas: 100% (1141/1141), done.
# /content/ByteTrack

# %%
# !pip install -r requirements.txt
# !pip install cython lap
# !python setup.py develop
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (2.6.0+cu124)
# Requirement already satisfied: opencv_python in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (4.11.0.86)
# Collecting loguru (from -r requirements.txt (line 5))
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (0.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (4.67.1)
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (0.21.0+cu124)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (11.2.1)
# Collecting thop (from -r requirements.txt (line 10))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Collecting ninja (from -r requirements.txt (line 11))
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 12)) (0.9.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 13)) (2.18.0)
# Collecting lap (from -r requirements.txt (line 14))
#   Downloading lap-0.5.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting motmetrics (from -r requirements.txt (line 15))
#   Downloading motmetrics-1.4.0-py3-none-any.whl.metadata (20 kB)
# Collecting filterpy (from -r requirements.txt (line 16))
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 17.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 17)) (3.14.0)
# Collecting onnx==1.8.1 (from -r requirements.txt (line 20))
#   Downloading onnx-1.8.1.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 85.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ERROR: Could not find a version that satisfies the requirement onnxruntime==1.8.0 (from versions: 1.15.0, 1.15.1, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.17.0, 1.17.1, 1.17.3, 1.18.0, 1.18.1, 1.19.0, 1.19.2, 1.20.0, 1.20.1, 1.21.0, 1.21.1, 1.22.0)
# ERROR: No matching distribution found for onnxruntime==1.8.0
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Collecting lap
#   Using cached lap-0.5.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from lap) (2.0.2)
# Downloading lap-0.5.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.9 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
# running develop
# /usr/local/lib/python3.11/dist-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running egg_info
# creating yolox.egg-info
# writing yolox.egg-info/PKG-INFO
# writing dependency_links to yolox.egg-info/dependency_links.txt
# writing top-level names to yolox.egg-info/top_level.txt
# writing manifest file 'yolox.egg-info/SOURCES.txt'
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py:529: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'yolox.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'yolox.egg-info/SOURCES.txt'
# running build_ext
# building 'yolox._C' extension
# creating build/temp.linux-x86_64-cpython-311/content/ByteTrack/yolox/layers/csrc/cocoeval
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/content/ByteTrack/yolox/layers/csrc -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/include/python3.11 -c /content/ByteTrack/yolox/layers/csrc/cocoeval/cocoeval.cpp -o build/temp.linux-x86_64-cpython-311/content/ByteTrack/yolox/layers/csrc/cocoeval/cocoeval.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/content/ByteTrack/yolox/layers/csrc -I/usr/local/lib/python3.11/dist-packages/torch/include -I/usr/local/lib/python3.11/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.11/dist-packages/torch/include/TH -I/usr/local/lib/python3.11/dist-packages/torch/include/THC -I/usr/include/python3.11 -c /content/ByteTrack/yolox/layers/csrc/vision.cpp -o build/temp.linux-x86_64-cpython-311/content/ByteTrack/yolox/layers/csrc/vision.o -O3 -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=_C -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# creating build/lib.linux-x86_64-cpython-311/yolox
# x86_64-linux-gnu-g++ -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -shared -Wl,-O1 -Wl,-Bsymbolic-functions build/temp.linux-x86_64-cpython-311/content/ByteTrack/yolox/layers/csrc/cocoeval/cocoeval.o build/temp.linux-x86_64-cpython-311/content/ByteTrack/yolox/layers/csrc/vision.o -L/usr/local/lib/python3.11/dist-packages/torch/lib -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -o build/lib.linux-x86_64-cpython-311/yolox/_C.cpython-311-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-311/yolox/_C.cpython-311-x86_64-linux-gnu.so -> yolox
# Creating /usr/local/lib/python3.11/dist-packages/yolox.egg-link (link to .)
# Adding yolox 0.1.0 to easy-install.pth file
#
# Installed /content/ByteTrack
# Processing dependencies for yolox==0.1.0
# Finished processing dependencies for yolox==0.1.0

# %%
# Print class names the model recognizes
print(model.names)
# Out:
# {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}

# %%
from ultralytics import YOLO

# Load the model
model = YOLO('/content/best.pt')  # 🔁 Use your trained model

# Run tracking on video (this uses ByteTrack by default)
model.track(
    source='/content/15sec_input_720p.mp4',   # 📹 Your input video
    conf=0.4,
    iou=0.5,
    tracker='bytetrack.yaml',       # 🧠 ByteTrack config (built-in)
    classes=[1, 2, 3],              # 🧍‍♂️ Track all except ball (class 0)
    save=True,
    project='/content',             # 💾 Save the result video
    name='tracked_output'           # 📁 Output directory: runs/track/tracked_output
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/375) /content/15sec_input_720p.mp4: 384x640 16 players, 2 referees, 73.3ms
# video 1/1 (frame 2/375) /content/15sec_input_720p.mp4: 384x640 15 players, 2 referees, 67.3ms
# video 1/1 (frame 3/375) /content/15sec_input_720p.mp4: 384x640 15 players, 2 referees, 67.3ms
# video 1/1 (frame 4/375) /content/15sec_input_720p.mp4: 384x640 14 players, 1 referee, 67.3ms
# video 1/1 (frame 5/375) /content/15sec_input_720p.mp4: 384x640 14 players, 2 referees, 46.8ms
# video 1/1 (frame 6/375) /content/15sec_input_720p.mp4: 384x640 14 players, 2 referees, 43.6ms
# video 1/1 (frame 7/375) /content/15sec_input_720p.mp4: 384x640 15 players, 1 referee, 42.7ms
# video 1/1 (frame 8/375) /content/15sec_input_720p.mp4: 384x640 15 players, 1 referee, 33.2ms
# video 1/1 (frame 9/375) /content/15sec_input_720p.mp4: 384x640 15 players, 1 referee, 33.4ms
# video 1/1 (frame 10/375) /content/15sec_input_720p.mp4: 384x640 15 players, 1 referee, 33.4ms
# video 1/1 (frame 11/375) /content/15sec_input_720p.mp4: 384x640 15 players, 2 referees, 33.2ms
# video 1/1 (frame 12/375) /content/15sec_input_720p.mp4: 384x640 15 players, 1 referee, 33.1ms
# video 1/1 (frame 13/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 32.7ms
# video 1/1 (frame 14/375) /content/15sec_input_720p.mp4: 384x640 14 players, 2 referees, 32.6ms
# video 1/1 (frame 15/375) /content/15sec_input_720p.mp4: 384x640 12 players, 2 referees, 33.3ms
# video 1/1 (frame 16/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 33.0ms
# video 1/1 (frame 17/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 33.1ms
# video 1/1 (frame 18/375) /content/15sec_input_720p.mp4: 384x640 14 players, 2 referees, 33.6ms
# video 1/1 (frame 19/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 33.6ms
# video 1/1 (frame 20/375) /content/15sec_input_720p.mp4: 384x640 12 players, 2 referees, 33.1ms
# video 1/1 (frame 21/375) /content/15sec_input_720p.mp4: 384x640 14 players, 1 referee, 33.3ms
# video 1/1 (frame 22/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 33.2ms
# video 1/1 (frame 23/375) /content/15sec_input_720p.mp4: 384x640 14 players, 3 referees, 33.2ms
# video 1/1 (frame 24/375) /content/15sec_input_720p.mp4: 384x640 14 players, 3 referees, 32.7ms
# video 1/1 (frame 25/375) /content/15sec_input_720p.mp4: 384x640 14 players, 2 referees, 33.4ms
# video 1/1 (frame 26/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 32.6ms
# video 1/1 (frame 27/375) /content/15sec_input_720p.mp4: 384x640 12 players, 1 referee, 33.2ms
# video 1/1 (frame 28/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 33.3ms
# video 1/1 (frame 29/375) /content/15sec_input_720p.mp4: 384x640 13 players, 2 referees, 33.2ms
# video 1/1 (frame 30/375) /content/15sec_input_720p.mp4: 384x640 12 players, 2 referees, 33.6ms
# video 1/1 (frame 31/375) /content/15sec_input_720p.mp4: 384x640 12 players, 2 referees, 33.8ms
# video 1/1 (frame 32/375) /content/15sec_input_720p.mp4: 384x640 12 players, 2 referees, 33.8ms
# video 1/1 (frame 33/375) /content/15sec_input_720p.mp4: 384x640 12 players, 2 referees, 32.4ms
# video 1/1 (frame 34/375) /content/15sec_input_720p.mp4: 384x640 14 players, 2 referees,
375) /content/15sec_input_720p.mp4: 384x640 8 players, 33.3ms
# video 1/1 (frame 340/375) /content/15sec_input_720p.mp4: 384x640 8 players, 34.1ms
# video 1/1 (frame 341/375) /content/15sec_input_720p.mp4: 384x640 8 players, 33.8ms
# video 1/1 (frame 342/375) /content/15sec_input_720p.mp4: 384x640 10 players, 33.8ms
# video 1/1 (frame 343/375) /content/15sec_input_720p.mp4: 384x640 9 players, 33.5ms
# video 1/1 (frame 344/375) /content/15sec_input_720p.mp4: 384x640 9 players, 33.2ms
# video 1/1 (frame 345/375) /content/15sec_input_720p.mp4: 384x640 9 players, 34.1ms
# video 1/1 (frame 346/375) /content/15sec_input_720p.mp4: 384x640 9 players, 34.1ms
# video 1/1 (frame 347/375) /content/15sec_input_720p.mp4: 384x640 9 players, 34.0ms
# video 1/1 (frame 348/375) /content/15sec_input_720p.mp4: 384x640 9 players, 33.7ms
# video 1/1 (frame 349/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.7ms
# video 1/1 (frame 350/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.7ms
# video 1/1 (frame 351/375) /content/15sec_input_720p.mp4: 384x640 9 players, 34.0ms
# video 1/1 (frame 352/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.6ms
# video 1/1 (frame 353/375) /content/15sec_input_720p.mp4: 384x640 13 players, 34.3ms
# video 1/1 (frame 354/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.7ms
# video 1/1 (frame 355/375) /content/15sec_input_720p.mp4: 384x640 12 players, 33.1ms
# video 1/1 (frame 356/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.7ms
# video 1/1 (frame 357/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.9ms
# video 1/1 (frame 358/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.7ms
# video 1/1 (frame 359/375) /content/15sec_input_720p.mp4: 384x640 10 players, 34.3ms
# video 1/1 (frame 360/375) /content/15sec_input_720p.mp4: 384x640 10 players, 33.9ms
# video 1/1 (frame 361/375) /content/15sec_input_720p.mp4: 384x640 10 players, 33.8ms
# video 1/1 (frame 362/375) /content/15sec_input_720p.mp4: 384x640 12 players, 33.8ms
# video 1/1 (frame 363/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.8ms
# video 1/1 (frame 364/375) /content/15sec_input_720p.mp4: 384x640 10 players, 34.3ms
# video 1/1 (frame 365/375) /content/15sec_input_720p.mp4: 384x640 10 players, 34.8ms
# video 1/1 (frame 366/375) /content/15sec_input_720p.mp4: 384x640 10 players, 33.4ms
# video 1/1 (frame 367/375) /content/15sec_input_720p.mp4: 384x640 10 players, 33.2ms
# video 1/1 (frame 368/375) /content/15sec_input_720p.mp4: 384x640 10 players, 33.3ms
# video 1/1 (frame 369/375) /content/15sec_input_720p.mp4: 384x640 11 players, 33.5ms
# video 1/1 (frame 370/375) /content/15sec_input_720p.mp4: 384x640 10 players, 33.7ms
# video 1/1 (frame 371/375) /content/15sec_input_720p.mp4: 384x640 10 players, 34.0ms
# video 1/1 (frame 372/375) /content/15sec_input_720p.mp4: 384x640 (no detections), 33.5ms
# video 1/1 (frame 373/375) /content/15sec_input_720p.mp4: 384x640 1 player, 35.7ms
# video 1/1 (frame 374/375) /content/15sec_input_720p.mp4: 384x640 (no detections), 32.6ms
# video 1/1 (frame 375/375) /content/15sec_input_720p.mp4: 384x640 (no detections), 35.2ms
# Speed: 2.4ms preprocess, 33.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/tracked_output
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 95,  78, 104],
#          [ 95,  78, 104],
#          [ 94,  77, 103],
#          ...,
#          [142, 161, 186],
#          [150, 169, 194],
#          [154, 173, 198]],
#
#         [[137, 120, 146],
#          [137, 120, 146],
#          [137, 120, 146],
#          ...,
#          [179, 198, 223],
#          [188, 207, 232],
#          [191, 210, 235]],
#
#         [[201, 184, 210],
#          [201, 184, 210],
#          [202, 185, 211],
#          ...,
#          [182, 201, 226],
#          [190, 209, 234],
#          [193, 212, 237]],
#
#         ...,
#
#         [[125, 135, 147],
#          [125, 135, 147],
#          [125, 135, 147],
#          ...,
#          [ 67, 101,  94],
#          [ 67, 101,  94],
#          [ 67, 101,  94]],
#
#         [[123, 133, 145],
#          [123, 133, 145],
#          [123, 133, 145],
#          ...,
#          [ 75, 109, 102],
#          [ 75, 109, 102],
#          [ 75, 109, 102]],
#
#         [[119, 129, 141],
#          [119, 129, 141],
#          [119, 129, 141],
#          ...,
#          [ 81, 115, 108],
#          [ 81, 115, 108],
#          [ 81, 115, 108]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 15.518662999966182, 'inference': 73.3015740000269, 'postprocess': 343.9433490000283},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[214, 205, 239],
#          [213, 204, 238],
#          [214, 206, 237],
#          ...,
#          [ 73,  86, 102],
#          [ 79,  93, 112],
#          [ 84,  98, 117]],
#
#         [[235, 226, 255],
#          [234, 225, 255],
#          [234, 226, 255],
#          ...,
#          [150, 163, 179],
#          [159, 173, 192],
#          [164, 178, 197]],
#
#         [[208, 199, 233],
#          [208, 199, 233],
#          [207, 199, 230],
#          ...,
#          [156, 169, 185],
#          [157, 171, 190],
#          [159, 173, 192]],
#
#         ...,
#
#         [[125, 135, 147],
#          [125, 135, 147],
#          [125, 135, 147],
#          ...,
#          [ 67, 101,  94],
#          [ 67, 101,  94],
#          [ 67, 101,  94]],
#
#         [[123, 133, 145],
#          [123, 133, 145],
#          [123, 133, 145],
#          ...,
#          [ 75, 109, 102],
#          [ 75, 109, 102],
#          [ 75, 109, 102]],
#
#         [[119, 129, 141],
#          [119, 129, 141],
#          [119, 129, 141],
#          ...,
#          [ 81, 115, 108],
#          [ 81, 115, 108],
#          [ 81, 115, 108]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.0158710000259816, 'inference': 67.34260899997935, 'postprocess': 2.408195999976215},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[106,  94, 137],
#          [ 86,  74, 117],
#          [ 63,  51,  94],
#          ...,
#          [  4,  21,  51],
#          [  6,  22,  49],
#          [  4,  20,  47]],
#
#         [[137, 125, 168],
#          [132, 120, 163],
#          [104,  92, 135],
#          ...,
#          [ 63,  80, 110],
#          [ 39,  55,  82],
#          [ 14,  30,  57]],
#
#         [[119, 107, 150],
#          [119, 107, 150],
#          [105,  93, 136],
#          ...,
#          [ 69,  86, 116],
#          [ 51,  67,  94],
#          [ 32,  48,  75]],
#
#         ...,
#
#         [[130, 140, 152],
#          [130, 140, 152],
#          [130, 140, 152],
#          ...,
#          [ 66, 103,  93],
#          [ 65, 102,  92],
#          [ 65, 102,  92]],
#
#         [[129, 139, 151],
#          [129, 139, 151],
#          [129, 139, 151],
#          ...,
#          [ 77, 114, 104],
#          [ 77, 114, 104],
#          [ 79, 116, 106]],
#
#         [[119, 129, 141],
#          [119, 129, 141],
#          [119, 129, 141],
#          ...,
#          [ 88, 125, 115],
#          [ 88, 125, 115],
#          [ 86, 123, 113]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.9028820000007727, 'inference': 67.34884600001578, 'postprocess': 1.8922009999755574},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 87,  86, 111],
#          [ 87,  86, 111],
#          [ 78,  74, 100],
#          ...,
#          [134, 139, 179],
#          [139, 147, 185],
#          [146, 154, 192]],
#
#         [[129, 128, 153],
#          [124, 123, 148],
#          [124, 120, 146],
#          ...,
#          [151, 156, 196],
#          [151, 159, 197],
#          [154, 162, 200]],
#
#         [[202, 201, 226],
#          [190, 189, 214],
#          [187, 183, 209],
#          ...,
#          [150, 155, 195],
#          [152, 160, 198],
#          [152, 160, 198]],
#
#         ...,
#
#         [[130, 140, 152],
#          [130, 140, 152],
#          [130, 140, 152],
#          ...,
#          [ 69, 103,  96],
#          [ 69, 103,  96],
#          [ 69, 103,  96]],
#
#         [[129, 139, 151],
#          [129, 139, 151],
#          [129, 139, 151],
#          ...,
#          [ 75, 109, 102],
#          [ 75, 109, 102],
#          [ 75, 109, 102]],
#
#         [[119, 129, 141],
#          [119, 129, 141],
#          [119, 129, 141],
#          ...,
#          [ 78, 112, 105],
#          [ 78, 112, 105],
#          [ 78, 112, 105]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 1.6862920000448867, 'inference': 67.25735499998109, 'postprocess': 1.883109000004879},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 75,  69,  95],
#          [ 73,  67,  93],
#          [ 75,  69,  95],
#          ...,
#          [ 92,  79, 132],
#          [ 90,  80, 132],
#          [ 89,  79, 131]],
#
#         [[ 65,  59,  85],
#          [ 66,  60,  86],
#          [ 71,  65,  91],
#          ...,
#          [ 85,  72, 125],
#          [ 82,  72, 124],
#          [ 81,  71, 123]],
#
#         [[ 64,  58,  84],
#          [ 69,  63,  89],
#          [ 77,  71,  97],
#          ...,
#          [ 83,  74, 115],
#          [ 78,  70, 115],
#          [ 75,  67, 112]],
#
#         ...,
#
#         [[131, 141, 153],
#          [131, 141, 153],
#          [131, 141, 153],
#          ...,
#          [ 64, 101,  91],
#          [ 64, 101,  91],
#          [ 64, 101,  91]],
#
#         [[126, 136, 148],
#          [126, 136, 148],
#          [126, 136, 148],
#          ...,
#          [ 81, 118, 108],
#          [ 81, 118, 108],
#          [ 81, 118, 108]],
#
#         [[119, 129, 141],
#          [119, 129, 141],
#          [119, 129, 141],
#          ...,
#          [ 72, 109,  99],
#          [ 72, 109,  99],
#          [ 72, 109,  99]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.8786679999939224, 'inference': 46.79466400000365, 'postprocess': 1.818603999993229},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[128, 105, 125],
#          [123, 100, 120],
#          [114,  93, 113],
#          ...,
#          [ 90,  83, 117],
#          [ 92,  83, 117],
#          [ 95,  86, 120]],
#
#         [[201, 178, 198],
#          [199, 176, 196],
#          [193, 172, 192],
#          ...,
#          [ 75,  68, 102],
#          [ 76,  67, 101],
#          [ 76,  67, 101]],
#
#         [[244, 221, 241],
#          [246, 223, 243],
#          [248, 227, 247],
#          ...,
#          [ 52,  44,  80],
#          [ 52,  42,  78],
#          [ 51,  41,  77]],
#
#         ...,
#
#         [[130, 140, 152],
#          [130, 140, 152],
#          [130, 140, 152],
#          ...,
#          [ 62,  96,  89],
#          [ 62,  96,  89],
#          [ 61,  95,  88]],
#
#         [[129, 139, 151],
#          [129, 139, 151],
#          [126, 136, 148],
#          ...,
#          [ 64,  98,  91],
#          [ 62,  96,  89],
#          [ 61,  95,  88]],
#
#         [[123, 133, 145],
#          [123, 133, 145],
#          [122, 132, 144],
#          ...,
#          [ 65,  99,  92],
#          [ 65,  99,  92],
#          [ 66, 100,  93]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 4.010786999970151, 'inference': 43.60983200001556, 'postprocess': 1.7596769999954631},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[111,  82,  98],
#          [106,  77,  93],
#          [110,  81,  97],
#          ...,
#          [ 78,  63, 134],
#          [ 76,  66, 118],
#          [ 71,  61, 113]],
#
#         [[106,  77,  93],
#          [100,  71,  87],
#          [106,  77,  93],
#          ...,
#          [ 80,  65, 136],
#          [ 79,  69, 121],
#          [ 76,  66, 118]],
#
#         [[108,  74, 112],
#          [104,  70, 108],
#          [108,  74, 112],
#          ...,
#          [ 81,  69, 131],
#          [ 80,  70, 120],
#          [ 79,  69, 119]],
#
#         ...,
#
#         [[126, 136, 148],
#          [126, 136, 148],
#          [126, 136, 148],
#          ...,
#          [ 59,  93,  86],
#          [ 56,  93,  83],
#          [ 56,  93,  83]],
#
#         [[120, 130, 142],
#          [120, 130, 142],
#          [120, 130, 142],
#          ...,
#          [ 60,  94,  87],
#          [ 59,  96,  86],
#          [ 58,  95,  85]],
#
#         [[116, 126, 138],
#          [116, 126, 138],
#          [116, 126, 138],
#          ...,
#          [ 69, 103,  96],
#          [ 67, 104,  94],
#          [ 66, 103,  93]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.601214999970125, 'inference': 42.65799499995637, 'postprocess': 1.7722639999533385},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 75,  69,  86],
#          [ 78,  72,  89],
#          [ 76,  71,  85],
#          ...,
#          [ 58,  47, 101],
#          [ 60,  46, 108],
#          [ 64,  50, 112]],
#
#         [[ 62,  56,  73],
#          [ 61,  55,  72],
#          [ 60,  55,  69],
#          ...,
#          [137, 126, 180],
#          [140, 126, 188],
#          [146, 132, 194]],
#
#         [[ 83,  77,  94],
#          [ 80,  74,  91],
#          [ 80,  75,  89],
#          ...,
#          [209, 198, 252],
#          [210, 198, 255],
#          [216, 204, 255]],
#
#         ...,
#
#         [[124, 134, 146],
#          [124, 134, 146],
#          [124, 134, 146],
#          ...,
#          [ 64,  98,  91],
#          [ 64,  98,  91],
#          [ 64,  98,  91]],
#
#         [[124, 134, 146],
#          [124, 134, 146],
#          [124, 134, 146],
#          ...,
#          [ 61,  95,  88],
#          [ 61,  95,  88],
#          [ 61,  95,  88]],
#
#         [[118, 128, 140],
#          [118, 128, 140],
#          [118, 128, 140],
#          ...,
#          [ 61,  95,  88],
#          [ 61,  95,  88],
#          [ 61,  95,  88]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.634702999955607, 'inference': 33.187709999992876, 'postprocess': 1.7578300000309355},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[115,  96, 122],
#          [122, 103, 129],
#          [125, 106, 132],
#          ...,
#          [ 78,  65,  88],
#          [ 78,  61,  96],
#          [ 79,  62,  97]],
#
#         [[123, 104, 130],
#          [120, 101, 127],
#          [124, 105, 131],
#          ...,
#          [ 95,  82, 105],
#          [ 94,  77, 112],
#          [101,  84, 119]],
#
#         [[116,  97, 123],
#          [113,  94, 120],
#          [115,  96, 122],
#          ...,
#          [122, 109, 132],
#          [123, 106, 141],
#          [128, 111, 146]],
#
#         ...,
#
#         [[129, 139, 151],
#          [129, 139, 151],
#          [129, 139, 151],
#          ...,
# ...
#          [160, 153, 195],
#          [164, 157, 199],
#          [172, 165, 207]],
#
#         ...,
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 61, 134, 105],
#          [ 61, 134, 105],
#          [ 61, 134, 105]],
#
#         [[ 35, 130,  97],
#          [ 35, 130,  97],
#          [ 35, 130,  97],
#          ...,
#          [ 55, 128,  99],
#          [ 55, 128,  99],
#          [ 55, 128,  99]],
#
#         [[ 34, 129,  96],
#          [ 34, 129,  96],
#          [ 34, 129,  96],
#          ...,
#          [ 50, 123,  94],
#          [ 50, 123,  94],
#          [ 50, 123,  94]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.596874999994725, 'inference': 34.842683000022134, 'postprocess': 3.194520000022294},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[137, 128, 201],
#          [130, 121, 194],
#          [113, 104, 177],
#          ...,
#          [150, 150, 183],
#          [159, 159, 192],
#          [165, 165, 198]],
#
#         [[136, 127, 200],
#          [130, 121, 194],
#          [113, 104, 177],
#          ...,
#          [149, 149, 182],
#          [159, 159, 192],
#          [168, 168, 201]],
#
#         [[135, 126, 199],
#          [128, 119, 192],
#          [110, 101, 174],
#          ...,
#          [152, 152, 185],
#          [160, 160, 193],
#          [172, 172, 205]],
#
#         ...,
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 55, 128,  99],
#          [ 55, 128,  99],
#          [ 55, 128,  99]],
#
#         [[ 35, 130,  97],
#          [ 35, 130,  97],
#          [ 35, 130,  97],
#          ...,
#          [ 50, 123,  94],
#          [ 50, 123,  94],
#          [ 50, 123,  94]],
#
#         [[ 34, 129,  96],
#          [ 34, 129,  96],
#          [ 34, 129,  96],
#          ...,
#          [ 50, 123,  94],
#          [ 50, 123,  94],
#          [ 50, 123,  94]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.4250440000059825, 'inference': 33.39901300000747, 'postprocess': 1.7547840000133874},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[132, 127, 190],
#          [125, 120, 183],
#          [108, 103, 166],
#          ...,
#          [152, 152, 185],
#          [150, 150, 183],
#          [154, 154, 187]],
#
#         [[123, 118, 181],
#          [116, 111, 174],
#          [ 99,  94, 157],
#          ...,
#          [149, 149, 182],
#          [146, 146, 179],
#          [153, 153, 186]],
#
#         [[118, 113, 176],
#          [111, 106, 169],
#          [ 94,  89, 152],
#          ...,
#          [138, 139, 178],
#          [133, 134, 173],
#          [138, 139, 178]],
#
#         ...,
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 54, 127,  98],
#          [ 54, 127,  98],
#          [ 54, 127,  98]],
#
#         [[ 35, 130,  97],
#          [ 35, 130,  97],
#          [ 35, 130,  97],
#          ...,
#          [ 50, 123,  94],
#          [ 50, 123,  94],
#          [ 50, 123,  94]],
#
#         [[ 34, 129,  96],
#          [ 34, 129,  96],
#          [ 34, 129,  96],
#          ...,
#          [ 50, 123,  94],
#          [ 50, 123,  94],
#          [ 50, 123,  94]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.2880600000121376, 'inference': 33.22086800000079, 'postprocess': 1.7747620000250208},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[136, 129, 197],
#          [127, 120, 188],
#          [108, 101, 169],
#          ...,
#          [157, 156, 186],
#          [170, 169, 199],
#          [179, 178, 208]],
#
#         [[131, 124, 192],
#          [122, 115, 183],
#          [103,  96, 164],
#          ...,
#          [167, 166, 196],
#          [165, 164, 194],
#          [163, 162, 192]],
#
#         [[122, 115, 183],
#          [113, 106, 174],
#          [ 94,  87, 155],
#          ...,
#          [161, 160, 190],
#          [163, 162, 192],
#          [164, 163, 193]],
#
#         ...,
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 60, 131, 102],
#          [ 60, 131, 102],
#          [ 60, 131, 102]],
#
#         [[ 35, 130,  97],
#          [ 35, 130,  97],
#          [ 35, 130,  97],
#          ...,
#          [ 55, 126,  97],
#          [ 55, 126,  97],
#          [ 55, 126,  97]],
#
#         [[ 34, 129,  96],
#          [ 34, 129,  96],
#          [ 34, 129,  96],
#          ...,
#          [ 56, 127,  98],
#          [ 56, 127,  98],
#          [ 56, 127,  98]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.280309000013858, 'inference': 33.25315799997952, 'postprocess': 2.018842999973458},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 95,  81, 170],
#          [ 89,  75, 164],
#          [ 85,  71, 160],
#          ...,
#          [119, 124, 142],
#          [126, 131, 149],
#          [152, 157, 175]],
#
#         [[101,  87, 176],
#          [ 94,  80, 169],
#          [ 89,  75, 164],
#          ...,
#          [132, 137, 155],
#          [145, 150, 168],
#          [178, 183, 201]],
#
#         [[116, 103, 188],
#          [109,  96, 181],
#          [106,  93, 178],
#          ...,
#          [143, 148, 166],
#          [161, 166, 184],
#          [192, 197, 215]],
#
#         ...,
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 67, 138, 109],
#          [ 67, 138, 109],
#          [ 67, 138, 109]],
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 66, 137, 108],
#          [ 66, 137, 108],
#          [ 66, 137, 108]],
#
#         [[ 35, 129,  98],
#          [ 35, 129,  98],
#          [ 35, 129,  98],
#          ...,
#          [ 64, 135, 106],
#          [ 64, 135, 106],
#          [ 64, 135, 106]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.0799380000084966, 'inference': 33.45378099999152, 'postprocess': 1.8366999999557265},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 74,  52, 164],
#          [ 68,  46, 158],
#          [ 64,  44, 150],
#          ...,
#          [131, 136, 154],
#          [121, 126, 144],
#          [113, 118, 136]],
#
#         [[ 74,  52, 164],
#          [ 68,  46, 158],
#          [ 64,  44, 150],
#          ...,
#          [119, 124, 142],
#          [113, 118, 136],
#          [111, 116, 134]],
#
#         [[ 75,  53, 165],
#          [ 70,  48, 160],
#          [ 63,  43, 149],
#          ...,
#          [106, 111, 129],
#          [113, 118, 136],
#          [124, 129, 147]],
#
#         ...,
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 68, 139, 110],
#          [ 68, 139, 110],
#          [ 68, 139, 110]],
#
#         [[ 36, 130,  99],
#          [ 36, 130,  99],
#          [ 36, 130,  99],
#          ...,
#          [ 64, 135, 106],
#          [ 64, 135, 106],
#          [ 64, 135, 106]],
#
#         [[ 35, 129,  98],
#          [ 35, 129,  98],
#          [ 35, 129,  98],
#          ...,
#          [ 63, 134, 105],
#          [ 63, 134, 105],
#          [ 63, 134, 105]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 1.759629000048335, 'inference': 33.681013999967035, 'postprocess': 1.8160340000008546},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 76,  55, 164],
#          [ 71,  50, 159],
#          [ 68,  50, 150],
#          ...,
#          [118, 120, 148],
#          [112, 114, 142],
#          [110, 112, 140]],
#
#         [[ 96,  75, 184],
#          [ 88,  67, 176],
#          [ 92,  74, 174],
#          ...,
#          [114, 116, 144],
#          [115, 117, 145],
#          [117, 119, 147]],
#
#         [[117,  99, 199],
#          [100,  82, 182],
#          [109,  94, 186],
#          ...,
#          [113, 115, 143],
#          [129, 131, 159],
#          [142, 144, 172]],
#
#         ...,
#
#         [[ 37, 131, 100],
#          [ 37, 131, 100],
#          [ 37, 131, 100],
#          ...,
#          [ 66, 137, 108],
#          [ 66, 137, 108],
#          [ 66, 137, 108]],
#
#         [[ 35, 130,  97],
#          [ 35, 130,  97],
#          [ 35, 130,  97],
#          ...,
#          [ 60, 131, 102],
#          [ 60, 131, 102],
#          [ 60, 131, 102]],
#
#         [[ 34, 129,  96],
#          [ 34, 129,  96],
#          [ 34, 129,  96],
#          ...,
#          [ 54, 125,  96],
#          [ 54, 125,  96],
#          [ 54, 125,  96]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.179382000008445, 'inference': 34.03888100001495, 'postprocess': 1.906531999964045},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 88, 128, 109],
#          [ 88, 128, 109],
#          [ 88, 128, 109],
#          ...,
#          [ 77, 135, 110],
#          [ 77, 135, 110],
#          [ 77, 135, 110]],
#
#         [[ 95, 135, 116],
#          [ 95, 135, 116],
#          [ 95, 135, 116],
#          ...,
#          [ 79, 137, 112],
#          [ 79, 137, 112],
#          [ 79, 137, 112]],
#
#         [[100, 140, 121],
#          [100, 140, 121],
#          [100, 140, 121],
#          ...,
#          [ 78, 136, 111],
#          [ 78, 136, 111],
#          [ 78, 136, 111]],
#
#         ...,
#
#         [[ 91, 139, 118],
#          [ 91, 139, 118],
#          [ 91, 139, 118],
#          ...,
#          [ 41,  63,  78],
#          [ 41,  63,  78],
#          [ 41,  63,  78]],
#
#         [[ 91, 139, 118],
#          [ 91, 139, 118],
#          [ 91, 139, 118],
#          ...,
#          [ 41,  63,  78],
#          [ 41,  63,  78],
#          [ 41,  63,  78]],
#
#         [[ 91, 139, 118],
#          [ 91, 139, 118],
#          [ 91, 139, 118],
#          ...,
#          [ 41,  63,  78],
#          [ 41,  63,  78],
#          [ 41,  63,  78]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.309367000009388, 'inference': 33.46527999997306, 'postprocess': 0.8808499999872765},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 86, 127, 105],
#          [ 86, 127, 105],
#          [ 86, 127, 105],
#          ...,
#          [ 36, 102,  82],
#          [ 36, 102,  82],
#          [ 36, 102,  82]],
#
#         [[ 92, 133, 111],
#          [ 92, 133, 111],
#          [ 92, 133, 111],
#          ...,
#          [ 40, 106,  86],
#          [ 40, 106,  86],
#          [ 40, 106,  86]],
#
#         [[ 97, 138, 116],
#          [ 97, 138, 116],
#          [ 97, 138, 116],
#          ...,
#          [ 41, 107,  87],
#          [ 41, 107,  87],
#          [ 41, 107,  87]],
#
#         ...,
#
#         [[ 86, 136, 117],
#          [ 86, 136, 117],
#          [ 86, 136, 117],
#          ...,
#          [155, 117, 101],
#          [163, 116,  97],
#          [163, 116,  97]],
#
#         [[ 83, 133, 114],
#          [ 83, 133, 114],
#          [ 83, 133, 114],
#          ...,
#          [154, 116, 100],
#          [162, 115,  96],
#          [162, 115,  96]],
#
#         [[ 80, 130, 111],
#          [ 80, 130, 111],
#          [ 80, 130, 111],
#          ...,
#          [153, 115,  99],
#          [161, 114,  95],
#          [161, 114,  95]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.1616849999759324, 'inference': 35.734687000001486, 'postprocess': 2.3419550000198797},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 81,  96, 119],
#          [ 81,  96, 119],
#          [ 81,  96, 119],
#          ...,
#          [ 34, 102,  82],
#          [ 34, 102,  82],
#          [ 34, 102,  82]],
#
#         [[ 86, 101, 124],
#          [ 86, 101, 124],
#          [ 86, 101, 124],
#          ...,
#          [ 38, 106,  86],
#          [ 38, 106,  86],
#          [ 38, 106,  86]],
#
#         [[ 91, 106, 129],
#          [ 91, 106, 129],
#          [ 91, 106, 129],
#          ...,
#          [ 39, 107,  87],
#          [ 39, 107,  87],
#          [ 39, 107,  87]],
#
#         ...,
#
#         [[ 78,  54, 147],
#          [ 78,  54, 147],
#          [ 78,  54, 147],
#          ...,
#          [161, 118,  87],
#          [161, 118,  87],
#          [161, 118,  87]],
#
#         [[ 75,  51, 144],
#          [ 75,  51, 144],
#          [ 75,  51, 144],
#          ...,
#          [161, 118,  87],
#          [161, 118,  87],
#          [161, 118,  87]],
#
#         [[ 73,  49, 142],
#          [ 73,  49, 142],
#          [ 73,  49, 142],
#          ...,
#          [161, 118,  87],
#          [161, 118,  87],
#          [161, 118,  87]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.062948000002507, 'inference': 32.63487500004203, 'postprocess': 0.8338800000160518},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#  obb: None
#  orig_img: array([[[ 54,  65,  98],
#          [ 54,  65,  98],
#          [ 54,  65,  98],
#          ...,
#          [ 29, 102,  81],
#          [ 29, 102,  81],
#          [ 29, 102,  81]],
#
#         [[ 54,  65,  98],
#          [ 54,  65,  98],
#          [ 54,  65,  98],
#          ...,
#          [ 32, 105,  84],
#          [ 32, 105,  84],
#          [ 32, 105,  84]],
#
#         [[ 54,  65,  98],
#          [ 54,  65,  98],
#          [ 54,  65,  98],
#          ...,
#          [ 34, 107,  86],
#          [ 34, 107,  86],
#          [ 34, 107,  86]],
#
#         ...,
#
#         [[ 33,  42,  96],
#          [ 34,  43,  97],
#          [ 34,  43,  97],
#          ...,
#          [ 87, 134, 117],
#          [ 87, 134, 117],
#          [ 87, 134, 117]],
#
#         [[ 33,  42,  96],
#          [ 34,  43,  97],
#          [ 34,  43,  97],
#          ...,
#          [ 85, 132, 115],
#          [ 85, 132, 115],
#          [ 85, 132, 115]],
#
#         [[ 33,  42,  96],
#          [ 34,  43,  97],
#          [ 34,  43,  97],
#          ...,
#          [ 80, 127, 110],
#          [ 80, 127, 110],
#          [ 80, 127, 110]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/15sec_input_720p.mp4'
#  probs: None
#  save_dir: '/content/tracked_output'
#  speed: {'preprocess': 2.1114859999897817, 'inference': 35.21479599999111, 'postprocess': 0.9002339999710784}]

# %%
# !ffmpeg -i /content/tracked_output/15sec_input_720p.avi \
        -c:v libx264 -preset fast -crf 22 \
        /content/tracked_output/15sec_input_720p.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, avi, from '/content/tracked_output/15sec_input_720p.avi':
#   Metadata:
#     software        : Lavf59.27.100
#   Duration: 00:00:15.00, start: 0.000000, bitrate: 28510 kb/s
#   Stream #0:0: Video: mjpeg (Baseline) (MJPG / 0x47504A4D), yuvj420p(pc, bt470bg/unknown/unknown), 1280x720, 28575 kb/s, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (mjpeg (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5a1a59cb4100] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x5a1a59cb4100] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5a1a59cb4100] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=2 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=6 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=crf mbtree=1 crf=22.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/tracked_output/15sec_input_720p.mp4':
#   Metadata:
#     software        : Lavf59.27.100
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuvj420p(pc, bt470bg/unknown/unknown, progressive), 1280x720, q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  375 fps= 16 q=-1.0 Lsize=    8790kB time=00:00:14.88 bitrate=4839.4kbits/s speed=0.625x
# video:8785kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.059427%
# [libx264 @ 0x5a1a59cb4100] frame I:3     Avg QP:21.22  size: 65373
# [libx264 @ 0x5a1a59cb4100] frame P:119   Avg QP:23.26  size: 38468
# [libx264 @ 0x5a1a59cb4100] frame B:253   Avg QP:25.56  size: 16686
# [libx264 @ 0x5a1a59cb4100] consecutive B-frames:  5.6% 10.1%  9.6% 74.7%
# [libx264 @ 0x5a1a59cb4100] mb I  I16..4: 16.8% 72.0% 11.2%
# [libx264 @ 0x5a1a59cb4100] mb P  I16..4:  5.7% 37.0%  4.6%  P16..4: 24.0% 11.9%  7.5%  0.0%  0.0%    skip: 9.3%
# [libx264 @ 0x5a1a59cb4100] mb B  I16..4:  2.5% 28.0%  0.8%  B16..8: 23.9% 11.3%  2.7%  direct: 9.1%  skip:21.6%  L0:43.0% L1:43.3% BI:13.7%
# [libx264 @ 0x5a1a59cb4100] 8x8 transform intra:84.6% inter:53.8%
# [libx264 @ 0x5a1a59cb4100] coded y,uvDC,uvAC intra: 59.7% 53.5% 8.5% inter: 21.0% 27.6% 6.1%
# [libx264 @ 0x5a1a59cb4100] i16 v,h,dc,p: 18% 67% 11%  4%
# [libx264 @ 0x5a1a59cb4100] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 56% 25%  1%  0%  0%  1%  0%  2%
# [libx264 @ 0x5a1a59cb4100] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 34% 11%  4%  4%  4%  5%  5%  4%
# [libx264 @ 0x5a1a59cb4100] i8c dc,h,v,p: 41% 41% 14%  4%
# [libx264 @ 0x5a1a59cb4100] Weighted P-Frames: Y:0.8% UV:0.0%
# [libx264 @ 0x5a1a59cb4100] ref P L0: 75.7% 24.3%
# [libx264 @ 0x5a1a59cb4100] ref B L0: 86.6% 13.4%
# [libx264 @ 0x5a1a59cb4100] ref B L1: 96.5%  3.5%
# [libx264 @ 0x5a1a59cb4100] kb/s:4797.46
